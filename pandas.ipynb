# %% [markdown]
# <a href="https://colab.research.google.com/github/DerinOgrenme2021/CihanCalisir/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
names=pd.Series(["cihan", "ali","veli"])

# %%
ages = pd.Series([23,13,16])

# %%
pd.DataFrame({"Name":names,"Ages":ages})
# Out:
#     Name  Ages
# 0  cihan    23
# 1    ali    13
# 2   veli    16
